# %% [markdown]
# # Assignment 4 – Docker
#
# **Graduate tasks are marked “CS 647 Only”**

# %% [markdown]
# ### 1.0 Install Docker Engine
#
# Install Docker CE from the official repository. You do not need to set up sudo-less access.

# %%
# verification
sudo docker --version
# Out:
# Docker version 28.1.1, build 4eba377

# %% [markdown]
# ### 1.1 Pull and List a Base Image
#
# Pull **`debian:latest`** and verify it appears in the local image list.

# %%
# YOUR COMMAND HERE
sudo docker pull debian:latest
# Out:
# latest: Pulling from library/debian
#
# Digest: sha256:264982ff4d18000fa74540837e2c43ca5137a53a83f8f62c7b3803c0f0bdcd56
# Status: Downloaded newer image for debian:latest
# docker.io/library/debian:latest

# %%
# verification
sudo docker images
# Out:
# REPOSITORY   TAG       IMAGE ID       CREATED      SIZE
# debian       latest    b2ab84c007fe   2 days ago   117MB

# %% [markdown]
# ### 1.2 Inspect Image Metadata
#
# Display the operating system and architecture of the `debian:latest` image.

# %%
# YOUR COMMAND HERE
sudo docker image inspect debian:latest --format='OS: {{.Os}}, Arch: {{.Architecture}}'
# Out:
# OS: linux, Arch: amd64

# %% [markdown]
# ### 1.3 Run a Container
#
# Run a container from `debian:latest` that prints **`Hello from Docker`**:
#
# ```bash
# /bin/echo "Hello from Docker"
# ```

# %%
# YOUR COMMAND HERE
sudo docker run debian:latest /bin/echo "Hello from Docker"
# Out:
# Hello from Docker

# %% [markdown]
# ### 1.4 Build a Custom Nginx Image
#
# Create a file **`index.html`** whose contents are exactly:
#
# ```
# Hello from a custom container
# ```
#
# Write a **`Dockerfile`** that:
#
# 1. Uses **`nginx:latest`** as the base image.
# 2. Copies `index.html` into `/usr/share/nginx/html/index.html`.
#
# Build the image and tag it **`nginx:cs447`**.

# %%
# YOUR COMMAND(S) HERE
# You can use the terminal to create the files,
# but your docker build command should be in here.
sudo docker build -t nginx:cs447 /home/alyssaaragon/nginx-custom
# Out:
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.2s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            0.2s
# [+] Building 0.4s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            0.3s
# [+] Building 0.5s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            0.4s
# [+] Building 0.7s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            0.6s
# [+] Building 0.8s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            0.8s
# [+] Building 1.0s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            0.9s
# [+] Building 1.1s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.1s
# [+] Building 1.3s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.2s
# [+] Building 1.4s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
# [+] Building 1.5s (2/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
# [+] Building 1.6s (3/6)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.0s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context:                                               0.0s
# [+] Building 1.7s (4/6)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.2s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d 0B / 28.23MB  0.1s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a324cf6a 0B / 44.15MB  0.1s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3bae2 0B / 629B  0.1s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
# [+] Building 1.9s (4/6)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.4s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d 0B / 28.23MB  0.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a324 1.05MB / 44.15MB  0.3s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce82 0B / 955B  0.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
# [+] Building 2.1s (4/6)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.6s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909c 4.19MB / 28.23MB  0.5s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 17.83MB / 44.15MB  0.5s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955c4 0B / 404B  0.5s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
# [+] Building 2.3s (4/6)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.8s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909c 7.34MB / 28.23MB  0.7s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 33.55MB / 44.15MB  0.7s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb473f0 0B / 1.21kB  0.7s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
# [+] Building 2.5s (4/6)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  1.0s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 11.53MB / 28.23MB  0.9s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  0.9s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
# [+] Building 2.7s (4/6)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  1.2s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 20.97MB / 28.23MB  1.1s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
# [+] Building 2.8s (4/6)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  1.3s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 27.26MB / 28.23MB  1.2s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
# [+] Building 3.0s (4/6)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  1.4s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 28.23MB / 28.23MB  1.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => => extracting sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d0a  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
# [+] Building 3.1s (4/6)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  1.5s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 28.23MB / 28.23MB  1.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => => extracting sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d0a  0.1s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
# [+] Building 3.2s (4/6)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  1.6s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 28.23MB / 28.23MB  1.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => => extracting sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d0a  0.2s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
# [+] Building 3.3s (4/6)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  1.8s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 28.23MB / 28.23MB  1.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => => extracting sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d0a  0.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
# [+] Building 3.4s (4/6)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  1.9s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 28.23MB / 28.23MB  1.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => => extracting sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d0a  0.4s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
# [+] Building 3.5s (4/6)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  2.0s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 28.23MB / 28.23MB  1.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => => extracting sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d0a  0.5s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
# [+] Building 3.6s (4/6)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  2.1s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 28.23MB / 28.23MB  1.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => => extracting sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d0a  0.7s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
# [+] Building 3.7s (4/6)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  2.2s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 28.23MB / 28.23MB  1.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => => extracting sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d0a  0.8s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
# [+] Building 3.8s (4/6)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  2.3s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 28.23MB / 28.23MB  1.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => => extracting sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d0a  0.9s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
# [+] Building 4.0s (4/6)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  2.5s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 28.23MB / 28.23MB  1.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => => extracting sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d0a  1.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
# [+] Building 4.1s (4/6)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  2.6s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 28.23MB / 28.23MB  1.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => => extracting sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d0a  1.1s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
# [+] Building 4.2s (4/6)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  2.7s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 28.23MB / 28.23MB  1.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => => extracting sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d0a  1.2s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
# [+] Building 4.3s (4/6)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  2.8s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 28.23MB / 28.23MB  1.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => => extracting sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d0a  1.4s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
# [+] Building 4.4s (4/6)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  2.9s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 28.23MB / 28.23MB  1.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => => extracting sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d0a  1.5s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
# [+] Building 4.6s (4/6)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  3.0s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 28.23MB / 28.23MB  1.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => => extracting sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d0a  1.6s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
# [+] Building 4.7s (4/6)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  3.2s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 28.23MB / 28.23MB  1.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => => extracting sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d0a  1.8s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
# [+] Building 4.8s (4/6)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  3.2s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 28.23MB / 28.23MB  1.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => => extracting sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d0a  1.8s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
# [+] Building 4.9s (4/6)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  3.4s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 28.23MB / 28.23MB  1.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => => extracting sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d0a  1.9s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
# [+] Building 4.9s (4/6)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  3.4s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 28.23MB / 28.23MB  1.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => => extracting sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d0a  2.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
# [+] Building 5.1s (4/6)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  3.6s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 28.23MB / 28.23MB  1.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => => extracting sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d0a  2.0s
#  => [internal] load build context                                          0.1s
# ...
#  => => extracting sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce8  0.0s
#  => => extracting sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955c  0.0s
#  => => extracting sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb473f04  0.0s
#  => => extracting sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b102166509c856  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
#  => [2/2] COPY index.html /usr/share/nginx/html/index.html                 0.2s
# [+] Building 7.7s (5/6)                                          docker:default
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  5.9s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 28.23MB / 28.23MB  1.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => => extracting sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d0a  2.0s
#  => => extracting sha256:91311529275035c77ef310fe38a81841c8f3e0a324cf6a68  1.6s
#  => => extracting sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3bae  0.0s
#  => => extracting sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce8  0.0s
#  => => extracting sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955c  0.0s
#  => => extracting sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb473f04  0.0s
#  => => extracting sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b102166509c856  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
#  => [2/2] COPY index.html /usr/share/nginx/html/index.html                 0.3s
# [+] Building 7.9s (6/6)                                          docker:default
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  5.9s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 28.23MB / 28.23MB  1.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => => extracting sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d0a  2.0s
#  => => extracting sha256:91311529275035c77ef310fe38a81841c8f3e0a324cf6a68  1.6s
#  => => extracting sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3bae  0.0s
#  => => extracting sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce8  0.0s
#  => => extracting sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955c  0.0s
#  => => extracting sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb473f04  0.0s
#  => => extracting sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b102166509c856  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
#  => [2/2] COPY index.html /usr/share/nginx/html/index.html                 0.4s
# [+] Building 8.0s (6/7)                                          docker:default
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 28.23MB / 28.23MB  1.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => => extracting sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d0a  2.0s
#  => => extracting sha256:91311529275035c77ef310fe38a81841c8f3e0a324cf6a68  1.6s
#  => => extracting sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3bae  0.0s
#  => => extracting sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce8  0.0s
#  => => extracting sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955c  0.0s
#  => => extracting sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb473f04  0.0s
#  => => extracting sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b102166509c856  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
#  => [2/2] COPY index.html /usr/share/nginx/html/index.html                 0.4s
#  => exporting to image                                                     0.2s
#  => => exporting layers                                                    0.2s
# [+] Building 8.0s (6/7)                                          docker:default
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 28.23MB / 28.23MB  1.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => => extracting sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d0a  2.0s
#  => => extracting sha256:91311529275035c77ef310fe38a81841c8f3e0a324cf6a68  1.6s
#  => => extracting sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3bae  0.0s
#  => => extracting sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce8  0.0s
#  => => extracting sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955c  0.0s
#  => => extracting sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb473f04  0.0s
#  => => extracting sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b102166509c856  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
#  => [2/2] COPY index.html /usr/share/nginx/html/index.html                 0.4s
#  => exporting to image                                                     0.2s
#  => => exporting layers                                                    0.2s
# [+] Building 8.2s (7/7)                                          docker:default
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 28.23MB / 28.23MB  1.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => => extracting sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d0a  2.0s
#  => => extracting sha256:91311529275035c77ef310fe38a81841c8f3e0a324cf6a68  1.6s
#  => => extracting sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3bae  0.0s
#  => => extracting sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce8  0.0s
#  => => extracting sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955c  0.0s
#  => => extracting sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb473f04  0.0s
#  => => extracting sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b102166509c856  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
#  => [2/2] COPY index.html /usr/share/nginx/html/index.html                 0.4s
#  => exporting to image                                                     0.3s
#  => => exporting layers                                                    0.2s
#  => => writing image sha256:26491bd6e451583b2a647bcdb446ba8c3a8e92e364391  0.0s
#  => => naming to docker.io/library/nginx:cs447                             0.0s
# [+] Building 8.4s (7/7)                                          docker:default
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 28.23MB / 28.23MB  1.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => => extracting sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d0a  2.0s
#  => => extracting sha256:91311529275035c77ef310fe38a81841c8f3e0a324cf6a68  1.6s
#  => => extracting sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3bae  0.0s
#  => => extracting sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce8  0.0s
#  => => extracting sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955c  0.0s
#  => => extracting sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb473f04  0.0s
#  => => extracting sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b102166509c856  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
#  => [2/2] COPY index.html /usr/share/nginx/html/index.html                 0.4s
#  => exporting to image                                                     0.3s
#  => => exporting layers                                                    0.2s
#  => => writing image sha256:26491bd6e451583b2a647bcdb446ba8c3a8e92e364391  0.0s
#  => => naming to docker.io/library/nginx:cs447                             0.0s
# [+] Building 8.5s (7/7)                                          docker:default
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 28.23MB / 28.23MB  1.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => => extracting sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d0a  2.0s
#  => => extracting sha256:91311529275035c77ef310fe38a81841c8f3e0a324cf6a68  1.6s
#  => => extracting sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3bae  0.0s
#  => => extracting sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce8  0.0s
#  => => extracting sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955c  0.0s
#  => => extracting sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb473f04  0.0s
#  => => extracting sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b102166509c856  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
#  => [2/2] COPY index.html /usr/share/nginx/html/index.html                 0.4s
#  => exporting to image                                                     0.3s
#  => => exporting layers                                                    0.2s
#  => => writing image sha256:26491bd6e451583b2a647bcdb446ba8c3a8e92e364391  0.0s
#  => => naming to docker.io/library/nginx:cs447                             0.0s
# [+] Building 8.5s (7/7) FINISHED                                 docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 104B                                       0.0s
#  => [internal] load metadata for docker.io/library/nginx:latest            1.4s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  5.9s
#  => => resolve docker.io/library/nginx:latest@sha256:c15da6c91de8d2f43619  0.1s
#  => => sha256:c15da6c91de8d2f436196f3a768483ad32c258ed4 10.25kB / 10.25kB  0.0s
#  => => sha256:88b3388ea06c7262e410a3ab5c05dc4088b7b39dea5 2.29kB / 2.29kB  0.0s
#  => => sha256:a830707172e8069c09cf6c67a04e23e5a1a332d70a9 8.58kB / 8.58kB  0.0s
#  => => sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909 28.23MB / 28.23MB  1.3s
#  => => sha256:91311529275035c77ef310fe38a81841c8f3e0a32 44.15MB / 44.15MB  1.0s
#  => => sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3ba 629B / 629B  0.2s
#  => => sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce 955B / 955B  0.5s
#  => => sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955 404B / 404B  0.6s
#  => => sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb4 1.21kB / 1.21kB  0.7s
#  => => sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b10216650 1.40kB / 1.40kB  0.9s
#  => => extracting sha256:254e724d77862dc53abbd3bf0e27f9d2f64293909cdd3d0a  2.0s
#  => => extracting sha256:91311529275035c77ef310fe38a81841c8f3e0a324cf6a68  1.6s
#  => => extracting sha256:3e544d53ce49d405a41bd59e97d102d77cc5412a717b3bae  0.0s
#  => => extracting sha256:4f21ed9ac0c04aa7c64ffd32df025f4545ab9f007d175ce8  0.0s
#  => => extracting sha256:d38f2ef2d6f270e6bc87cad48e49a5ec4ebdd2f5d1d4955c  0.0s
#  => => extracting sha256:40a6e9f4e4564bc7213f3983964e76c27e1dc94ceb473f04  0.0s
#  => => extracting sha256:d3dc5ec71e9d6d1a06a1740efb4a875b28b102166509c856  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 67B                                           0.0s
#  => [2/2] COPY index.html /usr/share/nginx/html/index.html                 0.4s
#  => exporting to image                                                     0.3s
#  => => exporting layers                                                    0.2s
#  => => writing image sha256:26491bd6e451583b2a647bcdb446ba8c3a8e92e364391  0.0s
#  => => naming to docker.io/library/nginx:cs447                             0.0s

# %%
# verification
sudo docker images | grep nginx | head
# Out:
# nginx        cs447     26491bd6e451   38 seconds ago   192MB

# %% [markdown]
# ### 1.5 Run the Custom Image on Host Port 8080

# %%
# YOUR COMMAND HERE
sudo docker run -d -p 8080:80 nginx:cs447
# Out:
# 3112b1ed0f645d89ec2d804d5bece7a5686ad95673733305c03f4e690cbe7125

# %%
# verification
curl -s http://localhost:8080 | head
# Out:
# Hello from a custom container

# %% [markdown]
# ### 1.6 Bind‑Mount a Persistent Host Directory
#
# 1. Create **`/opt/dockerdata`** on the host.
# 2. Add a file `host.txt` containing `hostfile`.
# 3. Run a one‑off Debian container that bind‑mounts `/opt/dockerdata` to `/data` and writes `container.txt` with `containerfile` inside the mount.

# %%
# YOUR COMMANDS HERE
# You can use the terminal to create the files,
# but your docker run command should be in here.
sudo docker run --rm -v /opt/dockerdata:/data debian:latest /bin/bash -c "echo 'containerfile' > /data/container.txt"

# %%
# verification
ls -l /opt/dockerdata
# Out:
# total 8
# -rw-r--r-- 1 root root 14 Apr 30 09:41 container.txt
# -rw-r--r-- 1 root root  9 Apr 30 09:40 host.txt

# %% [markdown]
# ### 1.7 Create and Use a **Named Volume**

# %% [markdown]
# Docker named volumes are convenient for persisting data without hard‑coding a host path.
#
# 1. Create a volume called **`cs447_data`**.
# 2. Run a one‑off container that mounts this volume at `/data` and writes a file `inside.txt` containing `namedvolume`.
# 3. Inspect the volume from the host to confirm it exists.

# %%
# YOUR COMMANDS HERE
sudo docker volume create cs447_data
sudo docker run --rm -v cs447_data:/data debian:latest /bin/bash -c "echo 'namedvolume' > /data/inside.txt"
sudo docker volume inspect cs447_data
# Out:
# cs447_data
# [
#     {
#         "CreatedAt": "2025-04-30T09:48:48-07:00",
#         "Driver": "local",
#         "Labels": null,
#         "Mountpoint": "/var/lib/docker/volumes/cs447_data/_data",
#         "Name": "cs447_data",
#         "Options": null,
#         "Scope": "local"
#     }
# ]

# %%
# verification
sudo docker volume ls
# Out:
# DRIVER    VOLUME NAME
# local     cs447_data

# %% [markdown]
# ### 1.8 Inspect Container Logs
# Run a command that displays the most recent 5 lines from the logs of your `cs447_web` container.

# %%
# YOUR COMMAND HERE
# You should see at least one log line showing the curl command from earlier
sudo docker logs --tail 5 3112b1ed0f64
# Out:
# 2025/04/30 16:38:20 [notice] 1#1: start worker process 29
# 2025/04/30 16:38:20 [notice] 1#1: start worker process 30
# 2025/04/30 16:38:20 [notice] 1#1: start worker process 31
# 2025/04/30 16:38:20 [notice] 1#1: start worker process 32
# 172.17.0.1 - - [30/Apr/2025:16:38:23 +0000] "GET / HTTP/1.1" 200 30 "-" "curl/7.88.1" "-"

# %% [markdown]
# ### 1.9 Run a Constrained Container
#
# Start a container named `secure_test` that:
#
# * Drops **all** capabilities (`--cap-drop ALL`)
# * Uses a **read‑only root filesystem** (`--read-only`)
# * Executes `/bin/true`

# %%
# YOUR COMMANDS HERE
sudo docker run --name secure_test --cap-drop ALL --read-only debian /bin/true

# %%
# verification
sudo docker inspect -f 'ReadonlyRootFS={{.HostConfig.ReadonlyRootfs}} CapDrop={{.HostConfig.CapDrop}}' secure_test
# Out:
# ReadonlyRootFS=true CapDrop=[ALL]

# %% [markdown]
# ### 1.10 CS 647 Only – Local Private Registry
#
# Graduate students must:
#
# 1. Run a registry container on port 5000.
# 2. Tag `nginx:cs447` as `localhost:5000/nginx:cs647` and push it.
# 3. Remove the local image and pull it back from the registry.
# 4. Run the image on host port 8081 to confirm it serves the custom page.

# %%
# YOUR COMMANDS HERE

# %%
# verification
curl -s http://localhost:8081 | head

# %% [markdown]
# ### 1.11 Cleanup - CS 447 and CS 647 (You will lose some points if you don't run this)

# %%
sudo docker stop $(sudo docker ps -q) 2>/dev/null || true
sudo docker rm $(sudo docker ps -aq) 2>/dev/null || true
sudo docker system prune -af
# Out:
# 3112b1ed0f64
# 990b36446775
# 3112b1ed0f64
# f3afec79e814
# Deleted Images:
# untagged: nginx:cs447
# deleted: sha256:26491bd6e451583b2a647bcdb446ba8c3a8e92e364391b25aaebdceb87173fd8
# untagged: debian:latest
# untagged: debian@sha256:264982ff4d18000fa74540837e2c43ca5137a53a83f8f62c7b3803c0f0bdcd56
# deleted: sha256:b2ab84c007feae81d95c5350d44ad7a54ea4693a79cb40fb05bd3fe00cbd4d26
# deleted: sha256:247fffb7158d7a68ad951dfdda7bf8af07ff4078d16abeb05bd3184effcad359
#
# Deleted build cache objects:
# od2e69m6i2yfwz8yt039fthp2
# wl5krftnc5hxj760vou5q2k42
# iirge67he4t20nbeiqery7p8x
# yi1vnhlhuidxnypxen2yt5oz7
# y2l6bth52ndgcyi2drrybfv3z
# l3v6w2bic16o40i0ofe4imqm9
# eo8jn5frkyfgoehy48jrtvcfl
# pt4mwu6xcnxi8buvlktg2iegj
# 1ms77a86pvcqi05dvmy5pl1c9
# xuh4ol1hfjnky0oztlhhvljn2
# 332l7e9p2178cfkbb5fems6j0
# q2j5fm8cucrfm1n8cnoqcuxd8
#
# Total reclaimed space: 116.6MB

# %%
# verification
sudo docker ps -a
# Out:
# CONTAINER ID   IMAGE     COMMAND   CREATED   STATUS    PORTS     NAMES
